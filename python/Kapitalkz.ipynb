# %%
import urllib.request
from bs4 import BeautifulSoup
import re
import requests
from datetime import date, timedelta

date_while = date.today()
xx = date_while.strftime('%Y-%m-%d')

channal = "https://kapital.kz/news"
for a in range(1, 5, 1):
    page = urllib.request.urlopen("https://kapital.kz/news?page=" + str(a))
    soup = BeautifulSoup(page)

    h = soup.find_all('a', {'class': 'main-news__name'})
    for h1 in h:
    #     if re.split('/',h1.get('href'))[1] == xx:
        post = "https://kapital.kz" + h1.get('href')
        page = urllib.request.urlopen(post)
        soup = BeautifulSoup(page)
        try:
            t = soup.find('div', {'class': 'article__body'})
            text = soup.find('h1', {'class': 'article__title'}).text + "\n"
            t1 = t.find_all('p', {'class': ''})
        except:
            t = soup.find('div', {'class': 'article__body'})
            text = soup.find('h1', {'class': 'longrid__title'}).text + "\n"
            t1 = t.find_all('p', {'class': ''})
        for t2 in t1:
            text = text + t2.text
        try:
            img = soup.find('img', {'class': ''})
        except:
            img = None
        date = soup.find('time').text
        d = re.findall('\d+', date)
        date_time = d[0]+'.'+d[1]+'.'+d[2]+' '+d[3]+':'+d[4]
        print(date_time + "\n")
# Out:
# 02.07.2021 14:00
#
# 02.07.2021 13:44
#
# 02.07.2021 13:44
#
# 02.07.2021 13:15
#
# 02.07.2021 13:00
#
# 02.07.2021 12:57
#
# 02.07.2021 12:15
#
# 02.07.2021 12:14
#
# 02.07.2021 11:24
#
# 02.07.2021 11:16
#
# 02.07.2021 11:13
#
# 02.07.2021 10:45
#
# 02.07.2021 10:14
#
# 02.07.2021 10:09
#
# 02.07.2021 09:00
#
# 02.07.2021 09:00
#
# 02.07.2021 08:10
#
# 02.07.2021 08:00
#
# 02.07.2021 08:00
#
# 02.07.2021 07:05
#
# 02.07.2021 06:30
#
# 01.07.2021 20:45
#
# 01.07.2021 20:40
#
# 01.07.2021 20:25
#
# 01.07.2021 20:15
#
# 01.07.2021 18:42
#
# 01.07.2021 17:54
#
# 01.07.2021 17:53
#
# 01.07.2021 17:15
#
# 01.07.2021 16:56
#
# 01.07.2021 16:55
#
# 01.07.2021 16:51
#
# 01.07.2021 16:12
#
# 01.07.2021 16:09
#
# 01.07.2021 16:04
#
# 01.07.2021 15:35
#
# 01.07.2021 14:50
#
# 01.07.2021 14:20
#
# 01.07.2021 14:10
#
# 01.07.2021 14:04
#
# 01.07.2021 13:40
#
# 01.07.2021 13:36
#
# 01.07.2021 13:05
#
# 01.07.2021 12:50
#
# 01.07.2021 12:29
#
# 01.07.2021 12:29
#
# 01.07.2021 12:06
#
# 01.07.2021 11:48
#
# 01.07.2021 11:17
#
# 01.07.2021 11:12
#
# 01.07.2021 11:05
#
# 01.07.2021 10:30
#
# 01.07.2021 10:23
#
# 01.07.2021 10:16
#
# 01.07.2021 10:06
#
# 01.07.2021 09:20
#
# 01.07.2021 09:00
#
# 01.07.2021 09:00
#
# 01.07.2021 09:00
#
# 01.07.2021 08:30
