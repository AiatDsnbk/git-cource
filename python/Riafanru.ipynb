# %%
#https://riafan.ru/news
import ibm_db_dbi as db
import requests
import re
from bs4 import BeautifulSoup
import urllib.request
import urllib
import psycopg2
from psycopg2 import Error
from datetime import date, timedelta
import datetime

def telegram_bot_sendtext(bot_message):
    bot_token = '1700296384:AAGoaq3o2WD7BbUthmU9dEYQD5IMEKBIgxU'
    bot_chatID = '771779345'
    send_text = 'https://api.telegram.org/bot' + bot_token + '/sendMessage?chat_id=' + bot_chatID + '&parse_mode=Markdown&text=' + bot_message
    response = requests.get(send_text)
    return response.json()

def converter(url):
    url = re.sub(r'[\W+\_]','',url)
    object_id = ''
    for u in url:
        object_id += str(ord(u) - 96)
    object_id = object_id.replace('-','')[:250]
    return object_id

try:
    url1 = 'https://riafan.ru/news'
    page = requests.get(url1)
    page.status_code
    soup = BeautifulSoup(page.text, 'html.parser')
    url_statyi = soup.find_all(class_ = 'cat-news-item')
    urls = []
    vi = []
    
    for i in range(len(url_statyi)):
        url2 = soup.find_all(class_ = 'cat-news-item')[i]
        url1 = url2.findAll('a')[0]["href"]
        
        v = url2.find(class_ = 'cat-item__views tile-list-news__views')
        view = v.get_text()
        vi.append(view)
        
        urls.append(url1)
        q = 0
        
    for i in range(len(urls)):
        URL = urls[i]
        url = urls[i][0:]
        object_id = converter(url)
        
        views = vi[i]
        
        page = requests.get(URL)
        page.status_code
        soup =  BeautifulSoup(page.text, 'html.parser')
        
        text1 = soup.find(class_ = 'content-wrap')
        text = text1.get_text()
        
        date = soup.find(class_ = 'post-published').get('datetime')
        d = re.findall('\d+', date)
        date_time = d[0] + '-' + d[1] + '-' + d[2] + ' ' + d[3] + ':' + d[4] + ':' + '00.0'
        
        time1 = d[3] + ':' + d[4] + ':' + '00'
        tlist = [time1, '3:00:00']
        mysum = datetime.timedelta()

        for i in tlist:
            (h, m, s) = i.split(':')
            dt = datetime.timedelta(hours = int(h), minutes = int(m), seconds = int(s))
            mysum += dt
            date = d[0] + '-' + d[1] + '-' + d[2] + ' ' + str(mysum) + '.0'
            
        try:
            img = soup.find('div', {'class': 'main-image-container'})
            url_attachment = img.find('img').get('data-src')
        except:
            url_attachment = None
        
        connection_text = """DATABASE=PRODDB;HOSTNAME=192.168.252.11;PORT=50000;
        PROTOCOL=TCPIP;UID=db2inst1;PWD=Qjuehnghj1;"""
        sql_1_test = "SELECT url_channel FROM TL_MEDIA_DATA_NEWS_TEST"
        con = db.connect(connection_text, "", "")
        cursor = con.cursor()
        cursor.execute(sql_1_test)
        t = cursor.fetchall()
        con.commit()
        cursor.close()
        con.close()
        
        t0 = []
        for y in range(len(t)):
            t0.append(t[y][0])
            
        if not URL in t0:
            connection_text = """DATABASE=PRODDB;HOSTNAME=192.168.252.11;
            PORT=50000;PROTOCOL=TCPIP;UID=db2inst1;PWD=Qjuehnghj1;"""
            con = db.connect(connection_text, "", "")
            cursor = con.cursor()
            insert_query = """insert into TL_MEDIA_DATA_NEWS_TEST (object_id, published_date, channel_id, 
            likes, comments, views, reposts, caption, text, url_attachment, url_channel, source_id) 
            values (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)"""
            cursor.execute(insert_query, (object_id, date, None, None, None, views, None, None, text, url_attachment, URL, 700))
            con.commit()
            cursor.close()
            con.close()
            q = q + 1
    #"Парсинг riafan.ru прошел успешно.(time.kz)" 
    send_text = "Парсинг сайта riafan.ru успешно прошло, добавлено " + str(q) + " публикации. Благодарю."
    telegram_bot_sendtext(send_text)   #Сообщение отправлено в телеграмм бот
    print(send_text)
except (Exception, psycopg2.Error) as error:
    send_text = "Ошибка при парсинге сайта riafan.ru " + "\n" + str(error)
    telegram_bot_sendtext(send_text)   #Сообщение отправлено в телеграмм бот
    print(send_text)
# Out:
# Парсинг сайта riafan.ru успешно прошло, добавлено 14 публикации. Благодарю.

# %%
import ibm_db_dbi as db
import requests
import re
from bs4 import BeautifulSoup
import urllib.request
import urllib

#Select data from table here
connection_text = """DATABASE=PRODDB;HOSTNAME=192.168.252.11;PORT=50000;
    PROTOCOL=TCPIP;UID=db2inst1;PWD=Qjuehnghj1;"""
con = db.connect(connection_text, "", "")
cursor = con.cursor()
cursor.execute("""
SELECT published_date
FROM TL_MEDIA_DATA_NEWS_TEST
WHERE source_id = '700'
ORDER BY published_date
""")
result = cursor.fetchall()
con.commit()
cursor.close()
con.close()
for x in result:
    print(x)
# Out:
# (datetime.datetime(25, 6, 12, 0, 0),)
# (datetime.datetime(26, 11, 12, 0, 0),)
# (datetime.datetime(36, 5, 12, 0, 0),)
# (datetime.datetime(2021, 7, 8, 15, 41),)
# (datetime.datetime(2021, 7, 8, 15, 42),)
# (datetime.datetime(2021, 7, 9, 5, 27),)
# (datetime.datetime(2021, 7, 9, 5, 36),)
# (datetime.datetime(2021, 7, 9, 5, 37),)
# (datetime.datetime(2021, 7, 9, 5, 40),)
# (datetime.datetime(2021, 7, 9, 5, 43),)
# (datetime.datetime(2021, 7, 9, 5, 50),)
# (datetime.datetime(2021, 7, 9, 5, 50),)
# (datetime.datetime(2021, 7, 9, 5, 57),)
# (datetime.datetime(2021, 7, 9, 6, 1),)
# (datetime.datetime(2021, 7, 9, 6, 14),)
# (datetime.datetime(2021, 7, 9, 6, 16),)
# (datetime.datetime(2021, 7, 9, 6, 20),)
# (datetime.datetime(2021, 7, 9, 6, 21),)
# (datetime.datetime(2021, 7, 9, 6, 26),)
# (datetime.datetime(2021, 7, 9, 6, 41),)
# (datetime.datetime(2021, 7, 9, 6, 42),)
# (datetime.datetime(2021, 7, 9, 6, 46),)
# (datetime.datetime(2021, 7, 9, 6, 46),)
# (datetime.datetime(2021, 7, 9, 6, 51),)
# (datetime.datetime(2021, 7, 9, 6, 54),)
# (datetime.datetime(2021, 7, 9, 7, 10),)
# (datetime.datetime(2021, 7, 9, 7, 12),)
# (datetime.datetime(2021, 7, 9, 7, 22),)
# (datetime.datetime(2021, 7, 9, 7, 39),)
# (datetime.datetime(2021, 7, 9, 7, 49),)
# (datetime.datetime(2021, 7, 9, 7, 56),)
# (datetime.datetime(2021, 7, 9, 7, 56),)
# (datetime.datetime(2021, 7, 9, 7, 58),)
# (datetime.datetime(2021, 7, 9, 8, 0),)
# (datetime.datetime(2021, 7, 9, 8, 0),)
# (datetime.datetime(2021, 7, 9, 8, 18),)
# (datetime.datetime(2021, 7, 9, 8, 21),)
# (datetime.datetime(2021, 7, 9, 8, 33),)
# (datetime.datetime(2021, 7, 9, 8, 51),)
# (datetime.datetime(2021, 7, 9, 8, 52),)
# (datetime.datetime(2021, 7, 9, 8, 56),)
# (datetime.datetime(2021, 7, 9, 8, 57),)
# (datetime.datetime(2021, 7, 9, 8, 57),)
# (datetime.datetime(2021, 7, 9, 12, 0),)
# (datetime.datetime(2021, 7, 9, 12, 0),)
# (datetime.datetime(2021, 7, 9, 12, 12),)
# (datetime.datetime(2021, 7, 9, 12, 17),)
# (datetime.datetime(2021, 7, 9, 14, 57),)
# (datetime.datetime(2021, 7, 9, 15, 0),)
# (datetime.datetime(2021, 7, 9, 15, 2),)
# (datetime.datetime(2021, 7, 9, 15, 2),)
# (datetime.datetime(2021, 7, 9, 15, 3),)
# (datetime.datetime(2021, 7, 9, 15, 6),)
# (datetime.datetime(2021, 7, 9, 15, 10),)
# (datetime.datetime(2021, 7, 9, 15, 10),)
# (datetime.datetime(2021, 7, 9, 15, 10),)
# (datetime.datetime(2021, 7, 9, 15, 11),)
# (datetime.datetime(2021, 7, 9, 15, 15),)
# (datetime.datetime(2021, 7, 9, 15, 15),)
# (datetime.datetime(2021, 7, 9, 15, 15),)
# (datetime.datetime(2021, 7, 9, 15, 16),)
# (datetime.datetime(2021, 7, 9, 15, 17),)
# (datetime.datetime(2021, 7, 9, 15, 19),)
# (datetime.datetime(2021, 7, 9, 15, 21),)
# (datetime.datetime(2021, 7, 9, 15, 22),)
# (datetime.datetime(2021, 7, 9, 15, 22),)
# (datetime.datetime(2021, 7, 9, 15, 23),)
# (datetime.datetime(2021, 7, 9, 16, 42),)
# (datetime.datetime(2021, 7, 9, 16, 43),)
# (datetime.datetime(2021, 7, 9, 16, 45),)
# (datetime.datetime(2021, 7, 9, 16, 45),)
# (datetime.datetime(2021, 7, 9, 16, 47),)
# (datetime.datetime(2021, 7, 9, 16, 48),)
# (datetime.datetime(2021, 7, 9, 16, 50),)
# (datetime.datetime(2021, 7, 9, 16, 50),)
# (datetime.datetime(2021, 7, 9, 16, 51),)
# (datetime.datetime(2021, 7, 9, 16, 53),)
# (datetime.datetime(2021, 7, 9, 16, 55),)
# (datetime.datetime(2021, 7, 9, 16, 56),)
# (datetime.datetime(2021, 7, 9, 16, 57),)
# (datetime.datetime(2021, 7, 9, 16, 59),)
# (datetime.datetime(2021, 7, 9, 17, 0),)
# (datetime.datetime(2021, 7, 9, 17, 0),)
# (datetime.datetime(2021, 7, 9, 17, 0),)
# (datetime.datetime(2021, 7, 9, 17, 4),)
# (datetime.datetime(2021, 7, 9, 17, 5),)
# (datetime.datetime(2021, 7, 9, 17, 6),)
# (datetime.datetime(2021, 7, 9, 17, 9),)
# (datetime.datetime(2021, 7, 9, 17, 12),)
# (datetime.datetime(2021, 7, 9, 17, 14),)
# (datetime.datetime(2021, 7, 9, 17, 15),)
# (datetime.datetime(2021, 7, 9, 17, 16),)
# (datetime.datetime(2021, 7, 9, 17, 16),)
# (datetime.datetime(2021, 7, 9, 17, 16),)
# (datetime.datetime(2021, 7, 9, 17, 16),)
# (datetime.datetime(2021, 7, 9, 17, 17),)
# (datetime.datetime(2021, 7, 9, 17, 21),)
# (datetime.datetime(2021, 7, 9, 17, 21),)
# (datetime.datetime(2021, 7, 9, 17, 21),)
# (datetime.datetime(2021, 7, 9, 17, 22),)
# (datetime.datetime(2021, 7, 9, 17, 24),)
# (datetime.datetime(2021, 7, 9, 17, 28),)
# (datetime.datetime(2021, 7, 9, 17, 28),)
# (datetime.datetime(2021, 7, 9, 17, 30),)
# (datetime.datetime(2021, 7, 9, 17, 31),)
# (datetime.datetime(2021, 7, 9, 17, 53),)
# (datetime.datetime(2021, 7, 9, 17, 54),)
# (datetime.datetime(2021, 7, 9, 17, 56),)
# (datetime.datetime(2021, 7, 9, 17, 58),)
# (datetime.datetime(2021, 7, 9, 17, 58),)
# (datetime.datetime(2021, 7, 9, 17, 58),)
# (datetime.datetime(2021, 7, 9, 17, 58),)
# (datetime.datetime(2021, 7, 9, 17, 58),)
# (datetime.datetime(2021, 7, 9, 18, 0),)
# (datetime.datetime(2021, 7, 9, 18, 0),)
# (datetime.datetime(2021, 7, 9, 18, 0),)
# (datetime.datetime(2021, 7, 9, 18, 4),)
# (datetime.datetime(2021, 7, 9, 18, 6),)
# (datetime.datetime(2021, 7, 9, 18, 9),)
# (datetime.datetime(2021, 7, 9, 18, 9),)
# (datetime.datetime(2021, 7, 9, 18, 12),)
# (datetime.datetime(2021, 7, 9, 18, 12),)
# (datetime.datetime(2021, 7, 9, 18, 12),)
# (datetime.datetime(2021, 7, 9, 18, 13),)
# (datetime.datetime(2021, 7, 9, 18, 14),)
# (datetime.datetime(2021, 7, 9, 18, 19),)
# (datetime.datetime(2021, 7, 9, 18, 20),)
# (datetime.datetime(2021, 7, 9, 18, 21),)
# (datetime.datetime(2021, 7, 9, 18, 23),)
# (datetime.datetime(2021, 7, 9, 18, 25),)
# (datetime.datetime(2021, 7, 9, 18, 26),)
# (datetime.datetime(2021, 7, 9, 18, 29),)
# (datetime.datetime(2021, 7, 9, 18, 29),)
# (datetime.datetime(2021, 7, 9, 18, 29),)
# (datetime.datetime(2021, 7, 9, 18, 31),)
# (datetime.datetime(2021, 7, 9, 18, 32),)
# (datetime.datetime(2021, 7, 9, 18, 34),)
# (datetime.datetime(2021, 7, 9, 18, 35),)
# (datetime.datetime(2021, 7, 9, 18, 35),)
# (datetime.datetime(2021, 7, 9, 18, 37),)
# (datetime.datetime(2021, 7, 9, 18, 41),)
# (datetime.datetime(2021, 7, 12, 8, 42),)
# (datetime.datetime(2021, 7, 12, 8, 45),)
# (datetime.datetime(2021, 7, 12, 8, 45),)
# (datetime.datetime(2021, 7, 12, 8, 47),)
# (datetime.datetime(2021, 7, 12, 8, 48),)
# (datetime.datetime(2021, 7, 12, 8, 57),)
# (datetime.datetime(2021, 7, 12, 9, 0),)
# (datetime.datetime(2021, 7, 12, 9, 3),)
# (datetime.datetime(2021, 7, 12, 9, 7),)
# (datetime.datetime(2021, 7, 12, 9, 13),)
# (datetime.datetime(2021, 7, 12, 9, 15),)
# (datetime.datetime(2021, 7, 12, 9, 20),)
# (datetime.datetime(2021, 7, 12, 9, 24),)
# (datetime.datetime(2021, 7, 12, 9, 34),)
# (datetime.datetime(2021, 7, 12, 9, 42),)
# (datetime.datetime(2021, 7, 12, 9, 56),)
# (datetime.datetime(2021, 7, 12, 10, 2),)
# (datetime.datetime(2021, 7, 12, 10, 2),)
# (datetime.datetime(2021, 7, 12, 10, 9),)
# (datetime.datetime(2021, 7, 12, 10, 14),)
# (datetime.datetime(2021, 7, 12, 10, 32),)
# (datetime.datetime(2021, 7, 12, 10, 38),)
# (datetime.datetime(2021, 7, 12, 10, 40),)
# (datetime.datetime(2021, 7, 12, 10, 54),)
# (datetime.datetime(2021, 7, 12, 10, 57),)
# (datetime.datetime(2021, 7, 12, 11, 0),)
# (datetime.datetime(2021, 7, 12, 11, 1),)
# (datetime.datetime(2021, 7, 12, 11, 7),)
# (datetime.datetime(2021, 7, 12, 11, 11),)
# (datetime.datetime(2021, 7, 12, 11, 16),)
# (datetime.datetime(2021, 7, 12, 11, 17),)
# (datetime.datetime(2021, 7, 12, 11, 19),)
# (datetime.datetime(2021, 7, 12, 11, 20),)
# (datetime.datetime(2021, 7, 12, 12, 17, 37),)
# (datetime.datetime(2021, 7, 12, 12, 19, 26),)
# (datetime.datetime(2021, 7, 12, 12, 19, 54),)
# (datetime.datetime(2021, 7, 12, 12, 21, 8),)
# (datetime.datetime(2021, 7, 12, 12, 21, 57),)
# (datetime.datetime(2021, 7, 12, 12, 22, 42),)
# (datetime.datetime(2021, 7, 12, 12, 22, 51),)
# (datetime.datetime(2021, 7, 12, 12, 24),)
# (datetime.datetime(2021, 7, 12, 12, 24, 6),)
# (datetime.datetime(2021, 7, 12, 12, 26),)
# (datetime.datetime(2021, 7, 12, 12, 28),)
# (datetime.datetime(2021, 7, 12, 12, 29),)
# (datetime.datetime(2021, 7, 12, 12, 31),)
# (datetime.datetime(2021, 7, 12, 12, 31),)
# (datetime.datetime(2021, 7, 12, 12, 32),)
# (datetime.datetime(2021, 7, 12, 12, 34),)
# (datetime.datetime(2021, 7, 12, 12, 37),)
# (datetime.datetime(2021, 7, 12, 12, 38),)
# (datetime.datetime(2021, 7, 12, 12, 40, 43),)
# (datetime.datetime(2021, 7, 12, 12, 41, 16),)
# (datetime.datetime(2021, 7, 12, 14, 22),)
# (datetime.datetime(2021, 7, 12, 14, 29),)
# (datetime.datetime(2021, 7, 12, 14, 29),)
# (datetime.datetime(2021, 7, 12, 14, 30),)
# (datetime.datetime(2021, 7, 12, 14, 31),)
# (datetime.datetime(2021, 7, 12, 14, 32),)
# (datetime.datetime(2021, 7, 12, 14, 33),)
# (datetime.datetime(2021, 7, 12, 14, 33),)
# (datetime.datetime(2021, 7, 12, 14, 34),)
# (datetime.datetime(2021, 7, 12, 14, 35),)
# (datetime.datetime(2021, 7, 12, 14, 36),)
# (datetime.datetime(2021, 7, 12, 14, 37),)
# (datetime.datetime(2021, 7, 12, 14, 37),)
# (datetime.datetime(2021, 7, 12, 14, 41),)
# (datetime.datetime(2021, 7, 12, 15, 23),)
# (datetime.datetime(2021, 7, 12, 15, 24),)
# (datetime.datetime(2021, 7, 12, 15, 25),)
# (datetime.datetime(2021, 7, 12, 15, 26),)
# (datetime.datetime(2021, 7, 12, 15, 29),)
# (datetime.datetime(2021, 7, 12, 15, 31),)
# (datetime.datetime(2021, 7, 12, 15, 31),)
# (datetime.datetime(2021, 7, 12, 15, 32),)
# (datetime.datetime(2021, 7, 12, 15, 33),)
# (datetime.datetime(2021, 7, 12, 15, 34),)
# (datetime.datetime(2021, 7, 12, 15, 38),)
# (datetime.datetime(2021, 7, 12, 15, 39),)
# (datetime.datetime(2021, 7, 12, 15, 39),)
# (datetime.datetime(2021, 7, 12, 15, 41),)
# (datetime.datetime(2021, 7, 12, 15, 42),)
# (datetime.datetime(2021, 7, 12, 15, 42),)
# (datetime.datetime(2021, 7, 12, 15, 42),)
# (datetime.datetime(2021, 7, 12, 15, 43),)
# (datetime.datetime(2021, 7, 12, 15, 43),)
# (datetime.datetime(2021, 7, 12, 15, 43),)
# (datetime.datetime(2021, 7, 12, 15, 43),)
# (datetime.datetime(2021, 7, 12, 15, 44),)
# (datetime.datetime(2021, 7, 12, 15, 44),)
# (datetime.datetime(2021, 7, 12, 15, 48),)
# (datetime.datetime(2021, 7, 12, 16, 24),)
# (datetime.datetime(2021, 7, 12, 16, 27),)
# (datetime.datetime(2021, 7, 12, 16, 27),)
# (datetime.datetime(2021, 7, 12, 16, 28),)
# (datetime.datetime(2021, 7, 12, 16, 29),)
# (datetime.datetime(2021, 7, 12, 16, 31),)
# (datetime.datetime(2021, 7, 12, 16, 31),)
# (datetime.datetime(2021, 7, 12, 16, 32),)
# (datetime.datetime(2021, 7, 12, 16, 35),)
# (datetime.datetime(2021, 7, 12, 16, 35),)
# (datetime.datetime(2021, 7, 12, 16, 35),)
# (datetime.datetime(2021, 7, 12, 16, 36),)
# (datetime.datetime(2021, 7, 12, 16, 37),)
# (datetime.datetime(2021, 7, 12, 16, 37),)
# (datetime.datetime(2021, 7, 12, 16, 38),)
# (datetime.datetime(2021, 7, 12, 16, 39),)
# (datetime.datetime(2021, 7, 12, 16, 40),)
# (datetime.datetime(2021, 7, 12, 16, 40),)
# (datetime.datetime(2021, 7, 12, 16, 41),)
# (datetime.datetime(2021, 7, 12, 16, 41),)
# (datetime.datetime(2021, 7, 12, 16, 41),)
# (datetime.datetime(2021, 7, 12, 16, 46),)
# (datetime.datetime(2021, 7, 12, 16, 48),)
# (datetime.datetime(2021, 7, 12, 16, 49),)
# (datetime.datetime(2021, 7, 12, 16, 50),)
# (datetime.datetime(2021, 7, 12, 16, 52),)
# (datetime.datetime(2021, 7, 12, 16, 54),)
# (datetime.datetime(2021, 7, 12, 16, 55),)
# (datetime.datetime(2021, 7, 12, 16, 56),)
# (datetime.datetime(2021, 7, 12, 16, 56),)
# (datetime.datetime(2021, 7, 12, 16, 57),)
# (datetime.datetime(2021, 7, 12, 17, 1),)
# (datetime.datetime(2021, 7, 12, 17, 16),)
# (datetime.datetime(2021, 7, 12, 17, 16),)
# (datetime.datetime(2021, 7, 12, 17, 23),)
# (datetime.datetime(2021, 7, 12, 17, 24),)
# (datetime.datetime(2021, 7, 12, 17, 25),)
# (datetime.datetime(2021, 7, 12, 17, 25),)
# (datetime.datetime(2021, 7, 12, 17, 35),)
# (datetime.datetime(2021, 7, 12, 17, 36),)
# (datetime.datetime(2021, 7, 12, 17, 37),)
# (datetime.datetime(2021, 7, 12, 17, 37),)
# (datetime.datetime(2021, 7, 12, 17, 38),)
# (datetime.datetime(2021, 7, 12, 17, 39),)
# (datetime.datetime(2021, 7, 12, 17, 39),)
# (datetime.datetime(2021, 7, 12, 17, 40),)
# (datetime.datetime(2021, 7, 12, 17, 41),)
# (datetime.datetime(2021, 7, 12, 17, 42),)
# (datetime.datetime(2021, 7, 12, 17, 44),)
# (datetime.datetime(2021, 7, 12, 17, 48),)
# (datetime.datetime(2021, 7, 12, 17, 48),)
# (datetime.datetime(2021, 7, 12, 17, 53),)
# (datetime.datetime(2021, 7, 12, 17, 55),)
# (datetime.datetime(2021, 7, 12, 17, 56),)
# (datetime.datetime(2021, 7, 12, 17, 57),)
# (datetime.datetime(2021, 7, 12, 17, 58),)
# (datetime.datetime(2021, 7, 12, 17, 59),)
# (datetime.datetime(2021, 7, 12, 18, 4),)
# (datetime.datetime(2021, 7, 12, 18, 4),)
# (datetime.datetime(2021, 7, 12, 18, 6),)
# (datetime.datetime(2021, 7, 12, 18, 7),)
# (datetime.datetime(2021, 7, 12, 18, 7),)
# (datetime.datetime(2021, 7, 12, 18, 8),)
# (datetime.datetime(2021, 7, 12, 18, 9),)
# (datetime.datetime(2021, 7, 12, 18, 11),)
# (datetime.datetime(2021, 7, 12, 18, 11),)
# (datetime.datetime(2021, 7, 12, 18, 12),)
# (datetime.datetime(2021, 7, 12, 18, 13),)
# (datetime.datetime(2021, 7, 12, 18, 18),)
# (datetime.datetime(2021, 7, 12, 18, 19),)
# (datetime.datetime(2021, 7, 12, 18, 20),)
# (datetime.datetime(2021, 7, 12, 18, 27),)
# (datetime.datetime(2021, 7, 12, 18, 28),)
# (datetime.datetime(2021, 7, 12, 18, 28),)
# (datetime.datetime(2021, 7, 12, 18, 29),)
# (datetime.datetime(2021, 7, 12, 18, 31),)
# (datetime.datetime(2021, 7, 12, 18, 32),)
# (datetime.datetime(2021, 7, 12, 18, 35),)
# (datetime.datetime(2021, 7, 13, 8, 30),)
# (datetime.datetime(2021, 7, 13, 8, 46),)
# (datetime.datetime(2021, 7, 13, 8, 51),)
# (datetime.datetime(2021, 7, 13, 8, 55),)
# (datetime.datetime(2021, 7, 13, 9, 0),)
# (datetime.datetime(2021, 7, 13, 9, 2),)
# (datetime.datetime(2021, 7, 13, 9, 9),)
# (datetime.datetime(2021, 7, 13, 9, 38),)
# (datetime.datetime(2021, 7, 13, 9, 41),)
# (datetime.datetime(2021, 7, 13, 9, 41),)
# (datetime.datetime(2021, 7, 13, 9, 46),)
# (datetime.datetime(2021, 7, 13, 9, 54),)
# (datetime.datetime(2021, 7, 13, 9, 58),)
# (datetime.datetime(2021, 7, 13, 10, 2),)
# (datetime.datetime(2021, 7, 13, 10, 6),)
# (datetime.datetime(2021, 7, 13, 10, 10),)
# (datetime.datetime(2021, 7, 13, 10, 13),)
# (datetime.datetime(2021, 7, 13, 10, 13),)
# (datetime.datetime(2021, 7, 13, 10, 15),)
# (datetime.datetime(2021, 7, 13, 10, 15),)
# (datetime.datetime(2021, 7, 13, 10, 16),)
# (datetime.datetime(2021, 7, 13, 10, 29),)
# (datetime.datetime(2021, 7, 13, 10, 42),)
# (datetime.datetime(2021, 7, 13, 10, 43),)
# (datetime.datetime(2021, 7, 13, 10, 44),)
# (datetime.datetime(2021, 7, 13, 10, 47),)
# (datetime.datetime(2021, 7, 13, 10, 49),)
# (datetime.datetime(2021, 7, 13, 10, 51),)
# (datetime.datetime(2021, 7, 13, 10, 53),)
# (datetime.datetime(2021, 7, 13, 10, 53),)

# %%
url1 = 'https://riafan.ru/news'
page = requests.get(url1)
page.status_code
soup = BeautifulSoup(page.text, 'html.parser')
url_statyi = soup.find_all(class_ = 'cat-news-item')
urls = []
vi = []

for i in range(len(url_statyi)):
    url2 = soup.find_all(class_ = 'cat-news-item')[i]
    url1 = url2.findAll('a')[0]["href"]

    v = url2.find(class_ = 'cat-item__views tile-list-news__views')
    view = v.get_text()
    vi.append(view)

    urls.append(url1)
    q = 0

for i in range(len(urls)):
    URL = urls[i]
    url = urls[i][0:]
    object_id = converter(url)

    views = vi[i]

    page = requests.get(URL)
    page.status_code
    soup =  BeautifulSoup(page.text, 'html.parser')

    text1 = soup.find(class_ = 'content-wrap')
    text = text1.get_text()

    date = soup.find(class_ = 'post-published').get('datetime')
    d = re.findall('\d+', date)
    date_time = d[0] + '-' + d[1] + '-' + d[2] + ' ' + d[3] + ':' + d[4] + ':' + '00.0'

    time1 = d[3] + ':' + d[4] + ':' + d[5]
    tlist = [time1, '3:00:00']
    mysum = datetime.timedelta()

    for i in tlist:
        (h, m, s) = i.split(':')
        dt = datetime.timedelta(hours = int(h), minutes = int(m), seconds = int(s))
        mysum += dt
        date = d[0] + '-' + d[1] + '-' + d[2] + ' ' + str(mysum) + '.0'
        
    try:
        img = soup.find('div', {'class': 'main-image-container'})
        url_attachment = img.find('img').get('data-src')
    except:
        url_attachment = None
    print(url_attachment)
# Out:
# None
# https://static.riafan.ru/uploads/2021/07/12/orig-21-1626083004.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-1626082479d7b94f766db787ec81691476216726e3.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-336-1626082334.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-1626082099Nq3OnBkqa6Bme98b1Fw9H4wHrzmfrivm6x7qfAWr.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-44-1626082839.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-1626080285XM6ZNI0N5z71xXrBpHz5Z45aLhxoJWlvs0htvd3w.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-16260818762a18RnEyUCGZddxnNsYCIizSOEEXp5X1rxNyz4tk.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-1626082215Hyvdsskrd0IbYoloigYrK47jxQ46cVASUKmaQXip.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-216-1626076073.jpeg
# None
# https://static.riafan.ru/uploads/2021/07/12/orig-1626080290bpaUklF30DK8zslO8rYHKuslGTxHsuEf7pPSHM33.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-209-1626082526.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-1626076978UdSY2LklNOnh8lwkZ79mHynH6eCjc23tRctngeah.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-209-1626081669.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-336-1626080297.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-263-1626082011.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-211-1626080059.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-230-1626082191.jpeg
# https://static.riafan.ru/uploads/2021/07/12/orig-353-1626081173.jpeg
