# %%
#alaukz
import urllib.request
from bs4 import BeautifulSoup
import re
import requests
from datetime import date, timedelta

date_while = date.today()
xx = date_while.strftime('%d.%m.%Y')

for i in range(1, 11, 1):
    page = urllib.request.urlopen("https://alau.kz/category/news/page/" + str(i) + "/")
    soup = BeautifulSoup(page)

    h = soup.find_all('div', {'class': 'post-content'})
    for h1 in h:
        date = h1.find('ul', {'class': 'post-meta-info'}).text
        d = re.findall('\d+', date)
        date_time = d[0]+'.'+d[1]+'.'+d[2]+' '+d[3] + ':' + d[4]
    # #     if re.search(xx, date):
        href = h1.find('a', {'': ''}).get('href')
    #     post = href
    #     page = urllib.request.urlopen(post)
    #     soup = BeautifulSoup(page)

    #     t = soup.find('div', {'class': 'entry-content clearfix'})
    #     text = soup.find('h1', {'class': 'post-title lg'}).text + "\n"
    #     t1 = t.find_all('p', {'class': ''})
    #     for t2 in t1:
    #         text = text + t2.text
        print(date_time + "\n")
# Out:
# 07.07.2021 18:00
#
# 07.07.2021 16:43
#
# 07.07.2021 14:14
#
# 07.07.2021 13:49
#
# 07.07.2021 13:09
#
# 07.07.2021 11:26
#
# 07.07.2021 10:54
#
# 07.07.2021 10:37
#
# 07.07.2021 10:29
#
# 07.07.2021 09:53
#
# 07.07.2021 09:48
#
# 07.07.2021 09:36
#
# 06.07.2021 17:30
#
# 06.07.2021 16:28
#
# 06.07.2021 15:17
#
# 06.07.2021 14:56
#
# 06.07.2021 09:05
#
# 05.07.2021 17:29
#
# 05.07.2021 14:37
#
# 04.07.2021 16:23
#
# 04.07.2021 14:43
#
# 04.07.2021 10:20
#
# 04.07.2021 09:42
#
# 04.07.2021 09:12
#
# 03.07.2021 18:40
#
# 03.07.2021 16:18
#
# 03.07.2021 14:26
#
# 03.07.2021 13:21
#
# 03.07.2021 11:51
#
# 03.07.2021 10:37
#
# 03.07.2021 09:45
#
# 03.07.2021 09:37
#
# 03.07.2021 09:35
#
# 02.07.2021 20:00
#
# 02.07.2021 17:04
#
# 02.07.2021 16:42
#
# 02.07.2021 15:43
#
# 02.07.2021 14:52
#
# 02.07.2021 14:26
#
# 02.07.2021 13:26
