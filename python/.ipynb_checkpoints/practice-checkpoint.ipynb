# %%
import psycopg2
from psycopg2 import Error

try:
    # Connect to an existing database
    connection = psycopg2.connect(user="tester",
                                  password="postgres",
                                  host="127.0.0.1",
                                  port="5432",
                                  database="testdb")

    # Create a cursor to perform database operations
    cursor = connection.cursor()
    # Print PostgreSQL details
    print("PostgreSQL server information")
    print(connection.get_dsn_parameters(), "\n")
    # Executing a SQL query
    cursor.execute("SELECT version();")
    # Fetch result
    record = cursor.fetchone()
    print("You are connected to - ", record, "\n")

except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if (connection):
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# PostgreSQL server information
# {'user': 'tester', 'channel_binding': 'prefer', 'dbname': 'testdb', 'host': '127.0.0.1', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'ssl_min_protocol_version': 'TLSv1.2', 'gssencmode': 'prefer', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 13.3 (Ubuntu 13.3-1.pgdg20.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0, 64-bit',)
#
# PostgreSQL connection is closed

# %%
import psycopg2
from psycopg2 import Error

try:
    connection = psycopg2.connect(user="tester",
                                  password="postgres",
                                  host="127.0.0.1",
                                  port="5432",
                                  database="testdb")

    cursor = connection.cursor()
    
    # SQL query to create a new table
    create_table_query = '''CREATE TABLE mobile
          (ID INT PRIMARY KEY     NOT NULL,
          MODEL           TEXT    NOT NULL,
          PRICE         REAL); '''
    
    # Execute a command: this creates a new table
    cursor.execute(create_table_query)
    connection.commit()
    print("Table created successfully in PostgreSQL ")

except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if connection:
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# Table created successfully in PostgreSQL
# PostgreSQL connection is closed

# %%
import psycopg2

try:
    connection = psycopg2.connect(user="tester",
                                  password="postgres",
                                  host="127.0.0.1",
                                  port="5432",
                                  database="testdb")
    cursor = connection.cursor()

    postgres_insert_query = """ INSERT INTO mobile (ID, MODEL, PRICE) VALUES (%s,%s,%s)"""
    record_to_insert = (4, 'One Plus 6', 950)
    cursor.execute(postgres_insert_query, record_to_insert)

    connection.commit()
    count = cursor.rowcount
    print(count, "Record inserted successfully into mobile table")

except (Exception, psycopg2.Error) as error:
    print("Failed to insert record into mobile table", error)

finally:
    # closing database connection.
    if connection:
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# 1 Record inserted successfully into mobile table
# PostgreSQL connection is closed

# %%
import psycopg2

try:
    connection = psycopg2.connect(user="tester",
                                  password="postgres",
                                  host="127.0.0.1",
                                  port="5432",
                                  database="testdb")

    cursor = connection.cursor()
    # Executing a SQL query to insert data into  table
    insert_query = """ INSERT INTO mobile (ID, MODEL, PRICE) VALUES (1, 'Iphone12', 1100)"""
    cursor.execute(insert_query)
    connection.commit()
    print("1 Record inserted successfully")
    # Fetch result
    cursor.execute("SELECT * from mobile")
    record = cursor.fetchall()
    print("Result ", record)

    # Executing a SQL query to update table
    update_query = """Update mobile set price = 1500 where id = 1"""
    cursor.execute(update_query)
    connection.commit()
    count = cursor.rowcount
    print(count, "Record updated successfully ")
    # Fetch result
    cursor.execute("SELECT * from mobile")
    print("Result ", cursor.fetchall())

    # Executing a SQL query to delete table
    delete_query = """Delete from mobile where id = 1"""
    cursor.execute(delete_query)
    connection.commit()
    count = cursor.rowcount
    print(count, "Record deleted successfully ")
    # Fetch result
    cursor.execute("SELECT * from mobile")
    print("Result ", cursor.fetchall())


except (Exception, psycopg2.Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if connection:
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# 1 Record inserted successfully
# Result  [(4, 'One Plus 6', 950.0), (1, 'Iphone12', 1100.0)]
# 1 Record updated successfully
# Result  [(4, 'One Plus 6', 950.0), (1, 'Iphone12', 1500.0)]
# 1 Record deleted successfully
# Result  [(4, 'One Plus 6', 950.0)]
# PostgreSQL connection is closed

# %%
import urllib.request
from bs4 import BeautifulSoup
import re
import requests
from datetime import date, timedelta

date_while = date.today()
xx = date_while.strftime('%d.%m.%Y')

page = urllib.request.urlopen("https://www.inform.kz/ru/vlast_g1")
soup = BeautifulSoup(page)

h = soup.find_all('div', {'class': 'lenta_news_block'})
for h1 in h:
    date = h1.find('div', {'class': 'lenta_news_time-rubric'}).text
    d = re.findall('\d+', date)
    date_time = d[0]+'.'+d[1]+'.'+d[2]+' '+d[3]+':'+d[4]
    #Today's news
#     if re.search(xx, date):
    href = h1.find('a', {'class': 'lenta_news_img'}).get('href')
    post = "https://www.inform.kz" + href
    page = urllib.request.urlopen(post)
    soup = BeautifulSoup(page)

    t = soup.find('div', {'class': 'article_news_body'})
    text = soup.find('div', {'class': 'article_title'}).text + "\n"
    t1 = t.find_all('p', {'class': ''})
    for t2 in t1:
        text = text + t2.text
    print(date_time + "\n" + text + "\n")
# Out:
# 29.06.2021 10:04
#   Ножевые ранения нанес трем членам семьи их родственник в СКО: начался суд
# ПЕТРОПАВЛОВСК. КАЗИНФОРМ – В Специализированном межрайонном суде по уголовным делам Северо-Казахстанской области началось разбирательство по делу о нападении родственника на членов семьи, передает корреспондент МИА «Казинформ». Трагедия произошла в марте этого года. 30-летний житель Алматы нанес ножевые ранения своим родственникам. 48-летняя женщина скончалась на операционном столе. Множественные ранения получил ее 28-летний сын. Позже в больнице, не приходя в сознание, скончалась 89-летняя пенсионерка, бабушка пострадавшего. Как выяснится в суде, чудом удалось спастись от родственника супруге молодого человека и младшей сестре. По информации пресс-службы областного суда, уголовное дело заняло восемь томов. Подсудимого Бекболата Габдуллина обвиняют по двум статьям: «Покушение на убийство» и «Убийство».
#
# 29.06.2021 09:57
#   200 экспертов из 20 стран обсудили вопросы электронного обучения  госслужащих
# НУР-СУЛТАН. КАЗИНФОРМ - Состоялась глобальная онлайн-конференция «Развитие человеческих ресурсов посредством электронного обучения: опыт стран», организованная Астанинским хабом государственной службы совместно с Министерством управления персоналом Республики Корея, Агентством Республики Казахстан по делам государственной службы и HR Ассоциацией Казахстана. Об этом передает МИА «Казинформ». В работе конференции приняли участие 200 экспертов, госслужащих и ученых из 20 стран Европы, Азии и Америки. В своей приветственной речи министр управления персоналом Республики Корея Ким Ву Ху отметил, что обучение играет решающую роль в повышении конкурентноспобности госслужащих во всех странах мира. В Республике Корея, в соответствии с тенденциями перехода к информационному обществу, активное внедрение электронного обучения было начато с 2000-х годов. С 2017 года все программы обучения объединены в Правительственную платформу электронного обучения. С 2020 года применяются передовые технологии искусственного интеллекта, разрабатывается open smart platform с целью развития человеческих ресурсов нового поколения. Он обозначил актуальность «системы самостоятельного электронного обучения в любом месте, в любое время, триста шестьдесят дней в году». Выступая с приветственным словом, председатель Агентства Республики Казахстан по делам государственной службы Анар Жаилганова подчеркнула, что государственная служба Казахстана доказала свою эффективность и способность адаптироваться к электронным форматам рабочих и учебных процессов, оперативно справляясь с вызовами кризиса, связанного с пандемией. Говоря об электронном обучении, Председатель Агентства сказала, что «онлайн формат обучения позволил расширить географию проводимых семинаров», отметив при этом роль Программы развития ООН и Хаба в организации обучения для развития цифровых навыков госслуж
ором Риддерского городского суда ВКО мужчины осуждены по статье 339 части 2 пункту 2 УК РК «Незаконное обращение с редкими и находящимися под угрозой исчезновения, а также запрещенными к использованию видами растений, группой лиц по предварительному сговору».«Осужденные получили три года ограничения свободы и поставлены на учет в службу пробации. В настоящий момент проводится профилактическая работа с подучетными, и в дальнейшем будут находиться на контроле в службе пробации. В случае повторного правонарушения данным лицам могут заменить ограничение свободы на более жесткий – лишение свободы. Правила отбывания наказания в виде ограничения свободы мужчинам были разъяснены», – подытожила начальник службы пробации города Риддер Альмира Майылханова.

# %%
url = 'http://vineoftheday.com/?order_by=rating'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# # Код для создания таблицы

# %%
import psycopg2
from psycopg2 import Error

try:
    connection = psycopg2.connect(user="tester",
                                  password="postgres",
                                  host="127.0.0.1",
                                  port="5432",
                                  database="testdb")

    cursor = connection.cursor()
    
    # SQL query to create a new table
    create_table_query = '''CREATE TABLE site3
          (ID SERIAL PRIMARY KEY NOT NULL,
          URLHREF TEXT NOT NULL,
          DATETIME TEXT NOT NULL,
          TEXT TEXT NOT NULL);'''
    
    # Execute a command: this creates a new table
    cursor.execute(create_table_query)
    connection.commit()
    print("Table created successfully in PostgreSQL ")

except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if connection:
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# Table created successfully in PostgreSQL
# PostgreSQL connection is closed

# %% [markdown]
# # Код для вставки базы данных в таблицу

# %%
import urllib.request
from bs4 import BeautifulSoup
import re
import requests
from datetime import date, timedelta

import psycopg2
from psycopg2 import Error

date_while = date.today()
xx = date_while.strftime('%d.%m.%Y')

page = urllib.request.urlopen("https://www.inform.kz/ru/vlast_g1")
soup = BeautifulSoup(page)

h = soup.find_all('div', {'class': 'lenta_news_block'})
a = 0
for h1 in h:
    a += 1
    date = h1.find('div', {'class': 'lenta_news_time-rubric'}).text
    d = re.findall('\d+', date)
    date_time = d[0]+'.'+d[1]+'.'+d[2]+' '+d[3]+':'+d[4]
#     if re.search(xx, date):
    href = h1.find('a', {'class': 'lenta_news_img'}).get('href')
    post = "https://www.inform.kz" + href
    page = urllib.request.urlopen(post)
    soup = BeautifulSoup(page)

    t = soup.find('div', {'class': 'article_news_body'})
    text = soup.find('div', {'class': 'article_title'}).text + "\n"
    t1 = t.find_all('p', {'class': ''})
    for t2 in t1:
        text = text + t2.text
    #         print(date + "\n" + post + "\n" + text + "\n")

    try:
        connection = psycopg2.connect(user="tester",
                                      password="postgres",
                                      host="127.0.0.1",
                                      port="5432",
                                      database="testdb")

        cursor = connection.cursor()
        # Executing a SQL query to insert data into  table
        insert_query = """INSERT INTO sites (ID, TITLE_HREF, DATE_TIME, WHOLE_TEXT) VALUES (%s, %s, %s, %s)"""
        values = (a, post, date_time, text)
        cursor.execute(insert_query, values)
        connection.commit()
        print("1 Record inserted successfully")
        # Deleting duplicates from table
        delete_query = """DELETE FROM sites a USING sites b WHERE a.id > b.id AND a.TITLE_HREF = b.TITLE_HREF;"""
        cursor.execute(delete_query)
        connection.commit()
        print("2 Duplicates deleted successfully")
        # Fetch result
        cursor.execute("SELECT * from sites")
        record = cursor.fetchall()
        print("Result ", record)

    except (Exception, psycopg2.Error) as error:
        print("Error while connecting to PostgreSQL", error)
    finally:
        if connection:
            cursor.close()
            connection.close()
            print("PostgreSQL connection is closed")
# Out:
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# PostgreSQL connection is closed

# %% [markdown]
# # Main code inform.kz

# %%
#https://www.inform.kz/ru/archive/1?date=17.06.2021
import urllib.request
from bs4 import BeautifulSoup
import re
import requests
from datetime import date, timedelta

import psycopg2
from psycopg2 import Error

date_while = date.today()
xx = date_while.strftime('%d.%m.%Y')

b = 0
for a in range(1, 15, 1):
    
    page = urllib.request.urlopen("https://www.inform.kz/ru/archive/" + str(a) + "?date=17.06.2021")
    soup = BeautifulSoup(page)

    h = soup.find_all('div', {'class': 'lenta_news_block'})
    for h1 in h:
        b += 1
        date = h1.find('div', {'class': 'lenta_news_time-rubric'}).text
        d = re.findall('\d+', date)
        date_time = d[0]+'.'+d[1]+'.'+d[2]+' '+d[3]+':'+d[4]
        if re.search(xx, date):
            href = h1.find('a', {'class': 'lenta_news_img'}).get('href')
            post = "https://www.inform.kz" + href
            page = urllib.request.urlopen(post)
            soup = BeautifulSoup(page)

            t = soup.find('div', {'class': 'article_news_body'})
            text = soup.find('div', {'class': 'article_title'}).text + "\n"
            t1 = t.find_all('p', {'class': ''})
            for t2 in t1:
                text = text + t2.text
        #         print(date + "\n" + post + "\n" + text + "\n")

        try:
            connection = psycopg2.connect(user="tester",
                                          password="postgres",
                                          host="127.0.0.1",
                                          port="5432",
                                          database="testdb")

            cursor = connection.cursor()
            # Executing a SQL query to insert data into  table
            insert_query = """INSERT INTO site3 (ID, TITLE_HREF, DATE_TIME, WHOLE_TEXT) VALUES (%s, %s, %s, %s)"""
            values = (b, post, date_time, text)
            cursor.execute(insert_query, values)
            connection.commit()
            print("1 Record inserted successfully")
            # Deleting duplicates from table
            delete_query = """DELETE FROM site3 a USING site3 b WHERE a.id < b.id AND a.TITLE_HREF = b.TITLE_HREF;"""
            cursor.execute(delete_query)
            connection.commit()
            print("2 Duplicates deleted successfully")
            # Fetch result
            cursor.execute("SELECT * from site2")
            record = cursor.fetchall()
            print("Result ", record)
            # Order by id
            orderby_id = """SELECT * FROM site3 ORDER BY id;"""
            cursor.execute(orderby_id)
            connection.commit()
            print("3 Ordered by ID successfully")

        except (Exception, psycopg2.Error) as error:
            print("Error while connecting to PostgreSQL", error)
        finally:
            if connection:
                cursor.close()
                connection.close()
                print("PostgreSQL connection is closed")
# Out:
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed
# 1 Record inserted successfully
# 2 Duplicates deleted successfully
# Result  []
# 3 Ordered by ID successfully
# PostgreSQL connection is closed

# %%
import urllib.request
from bs4 import BeautifulSoup
import re
import requests
from datetime import date, timedelta

date_while = date.today()
xx = date_while.strftime('%d.%m.%Y')
b = 0
for a in range(1, 15, 1):
    
    page = urllib.request.urlopen("https://www.inform.kz/ru/archive/" + str(a) + "?date=18.06.2021")
    soup = BeautifulSoup(page)

    h = soup.find_all('div', {'class': 'lenta_news_block'})
    for h1 in h:
        b += 1
        date = h1.find('div', {'class': 'lenta_news_time-rubric'}).text
        if re.search(xx, date):
            href = h1.find('a', {'class': 'lenta_news_img'}).get('href')
            post = "https://www.inform.kz" + href
            page = urllib.request.urlopen(post)
            soup = BeautifulSoup(page)

            t = soup.find('div', {'class': 'article_news_body'})
            text = soup.find('div', {'class': 'article_title'}).text + "\n"
            t1 = t.find_all('p', {'class': ''})
# %% [markdown]
# # Inform.kz DB

# %%
#https://www.inform.kz/ru/archive/1?date=17.06.2021
import urllib.request
from bs4 import BeautifulSoup
import re
import requests
from datetime import date, timedelta

import psycopg2
from psycopg2 import Error

date_while = date.today()
xx = date_while.strftime('%d.%m.%Y')

b = 0
for a in range(1, 15, 1):
    
    page = urllib.request.urlopen("https://www.inform.kz/ru/archive/" + str(a) + "?date=17.06.2021")
    soup = BeautifulSoup(page)

    h = soup.find_all('div', {'class': 'lenta_news_block'})
    for h1 in h:
        b += 1
        date = h1.find('div', {'class': 'lenta_news_time-rubric'}).text
        d = re.findall('\d+', date)
        date_time = d[0]+'.'+d[1]+'.'+d[2]+' '+d[3]+':'+d[4]
        if re.search(xx, date):
            href = h1.find('a', {'class': 'lenta_news_img'}).get('href')
            post = "https://www.inform.kz" + href
            page = urllib.request.urlopen(post)
            soup = BeautifulSoup(page)

            t = soup.find('div', {'class': 'article_news_body'})
            text = soup.find('div', {'class': 'article_title'}).text + "\n"
            t1 = t.find_all('p', {'class': ''})
            for t2 in t1:
                text = text + t2.text
        #         print(date + "\n" + post + "\n" + text + "\n")

        try:
            connection = psycopg2.connect(user="tester",
                                          password="postgres",
                                          host="127.0.0.1",
                                          port="5432",
                                          database="testdb")

            cursor = connection.cursor()
            cursor.execute("SELECT * from site2")
            record = cursor.fetchall()
            print("Result ", record)
            # Executing a SQL query to insert data into  table
            insert_query = """INSERT INTO site3 (ID, TITLE_HREF, DATE_TIME, WHOLE_TEXT) VALUES (%s, %s, %s, %s)"""
            values = (b, post, date_time, text)
            cursor.execute(insert_query, values)
            connection.commit()
            print("1 Record inserted successfully")
#             # Deleting duplicates from table
#             delete_query = """DELETE FROM site3 a USING site3 b WHERE a.id < b.id AND a.TITLE_HREF = b.TITLE_HREF;"""
#             cursor.execute(delete_query)
#             connection.commit()
#             print("2 Duplicates deleted successfully")
            # Fetch result
            
#             # Order by id
#             orderby_id = """SELECT * FROM site3 ORDER BY id;"""
#             cursor.execute(orderby_id)
#             connection.commit()
#             print("3 Ordered by ID successfully")

        except (Exception, psycopg2.Error) as error:
            print("Error while connecting to PostgreSQL", error)
        finally:
            if connection:
                cursor.close()
                connection.close()
                print("PostgreSQL connection is closed")
# Out:
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(1)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(2)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(3)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(4)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(5)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(6)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(7)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(8)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(9)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(10)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(11)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(12)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(13)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(14)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(15)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(16)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(17)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(18)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(19)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(20)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(21)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(22)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(23)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(24)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(25)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(26)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(27)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(28)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(29)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(30)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(31)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(32)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(33)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(34)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(35)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(36)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(37)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(38)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(39)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(40)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(41)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(42)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(43)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(44)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(45)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(46)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(47)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(48)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(49)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(50)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(51)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(52)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(53)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(54)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(55)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(56)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(57)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(58)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(59)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(60)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(61)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(62)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(63)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(64)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(65)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(66)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(67)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(68)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(69)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(70)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(71)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(72)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(73)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(74)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(75)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(76)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(77)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(78)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(79)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# Error while connecting to PostgreSQL ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "site3_pkey"
# DETAIL:  Ключ "(id)=(80)" уже существует.
#
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
# Result  []
# 1 Record inserted successfully
# PostgreSQL connection is closed
